# %%
import networkx as nx
from networkx.algorithms import community
import matplotlib.pyplot as plt

# %%
# 数据加载
G = nx.read_gml('football.gml')
# 可视化
nx.draw(G, with_labels=True)
plt.show()
# Out:
# D:\software\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
# 社区发现
communities = list(community.label_propagation_communities(G))
print(communities)
print(len(communities))
# Out:
# [{'Akron', 'Ohio', 'BowlingGreenState', 'MiamiOhio', 'Kent', 'Marshall', 'Connecticut', 'Buffalo'}, {'BostonCollege', 'Pittsburgh', 'NotreDame', 'WestVirginia', 'Syracuse', 'VirginiaTech', 'MiamiFlorida', 'Navy', 'Rutgers', 'Temple'}, {'Utah', 'Wyoming', 'NevadaLasVegas', 'NewMexico', 'AirForce', 'ColoradoState', 'SanDiegoState', 'BrighamYoung'}, {'Northwestern', 'Indiana', 'OhioState', 'Michigan', 'Illinois', 'Iowa', 'Minnesota', 'PennState', 'Wisconsin', 'MichiganState', 'Purdue'}, {'Kansas', 'TexasTech', 'Colorado', 'IowaState', 'Nebraska', 'Texas', 'Missouri', 'Baylor', 'KansasState', 'Oklahoma', 'OklahomaState', 'TexasA&M'}, {'WakeForest', 'FloridaState', 'NorthCarolina', 'Maryland', 'Duke', 'NorthCarolinaState', 'Clemson', 'Virginia', 'GeorgiaTech'}, {'SouthernCalifornia', 'ArizonaState', 'Oregon', 'WashingtonState', 'UtahState', 'OregonState', 'BoiseState', 'Arizona', 'Washington', 'California', 'NorthTexas', 'Idaho', 'NewMexicoState', 'Stanford', 'UCLA', 'ArkansasState'}, {'AlabamaBirmingham', 'EastCarolina', 'Cincinnati', 'Houston', 'Memphis', 'Tulane', 'SouthernMississippi', 'Louisville', 'Army'}, {'Vanderbilt', 'SouthCarolina', 'LouisianaMonroe', 'LouisianaState', 'Tennessee', 'Georgia', 'MississippiState', 'Alabama', 'Arkansas', 'Florida', 'LouisianaLafayette', 'CentralFlorida', 'Auburn', 'MiddleTennesseeState', 'LouisianaTech', 'Kentucky', 'Mississippi'}, {'FresnoState', 'Tulsa', 'TexasChristian', 'SouthernMethodist', 'SanJoseState', 'Rice', 'Nevada', 'Hawaii', 'TexasElPaso'}, {'EasternMichigan', 'BallState', 'Toledo', 'WesternMichigan', 'NorthernIllinois', 'CentralMichigan'}]
# 11
